# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 174
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "### Conditionals"
#       8    ]
#       9   },
#      10   {
#      11    "cell_type": "markdown",
#      12    "metadata": {},
#      13    "source": [
#      14     "A conditional is a construct that allows you to branch your code based on conditions being met (or not)"
#      15    ]
#      16   },
#      17   {
#      18    "cell_type": "markdown",
#      19    "metadata": {},
#      20    "source": [
#      21     "This is achieved using **if**, **elif** and **else** or the **ternary operator** (aka conditional expression)"
#      22    ]
#      23   },
#      24   {
#      25    "cell_type": "code",
#      26    "execution_count": 2,
# ...

# %% [markdown]
# Normal If-else statments.

# %% [markdown]
# ### Ternary Operator (Single Line if Else Block).

# %%
a = 20
b = 'a<10' if a < 10 else 'a>=10'
b
# Out:
# 'a>=10'

# %%
print(b)
# Out:
# a>=10

# %%
a = 9
'a<10' if a < 10 else 'a>=10'
# Out:
# 'a<10'
